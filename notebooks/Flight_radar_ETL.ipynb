# %% [markdown]
# # ✈️ FlightRadar24 - ETL & Airflow Pipeline
#
# ## Objectif
#
# Ce projet a pour but de construire un pipeline **ETL industrialisé**, tolérant aux erreurs et observable, qui récupère les données de vol en temps réel depuis l’API FlightRadar24 toutes les **2 heures**, les nettoie, les transforme, puis les stocke sous **format Parquet**.
# Ces données sont ensuite analysées via **PySpark** pour générer des **indicateurs métier** sur le trafic aérien mondial.

# %% [markdown]
# ### Installation des dépendances pour le projet

# %%
# !pip install --upgrade FlightRadarAPI pandas pyarrow
# Out:
# Requirement already satisfied: FlightRadarAPI in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.3.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (20.0.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.11/dist-packages (from FlightRadarAPI) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from FlightRadarAPI) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->FlightRadarAPI) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->FlightRadarAPI) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->FlightRadarAPI) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->FlightRadarAPI) (2025.7.14)

# %%
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in /usr/local/lib/python3.11/dist-packages (2.0.1)

# %% [markdown]
# ##### Lister toutes les méthodes publiques de l'instance

# %%
from FlightRadar24 import FlightRadar24API
import inspect, textwrap, pprint

fr_api = FlightRadar24API()

# %%
api_methods = sorted(
    m for m in dir(fr_api)
    if not m.startswith("_") and inspect.ismethod(getattr(fr_api, m))
)

pprint.pprint(textwrap.wrap(", ".join(api_methods), width=100))
# Out:
# ['get_airline_logo, get_airlines, get_airport, get_airport_details, '
#  'get_airport_disruptions,',
#  'get_airports, get_bookmarks, get_bounds, get_bounds_by_point, '
#  'get_country_flag, get_flight_details,',
#  'get_flight_tracker_config, get_flights, get_history_data, get_login_data, '
#  'get_most_tracked,',
#  'get_volcanic_eruptions, get_zones, is_logged_in, login, logout, search, '
#  'set_flight_tracker_config']

# %% [markdown]
# ## Extarct data from flight radar api

# %%
####################
#                  #
# Authored BY : me #
#                  #
####################

# Extract data from flightRadar api sous format dataframe

import pandas as pd
import logging
from math import radians, sin, cos, sqrt, atan2
from FlightRadar24 import FlightRadar24API

# Setup du logger
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)


def haversine(lat1, lon1, lat2, lon2):
    if None in (lat1, lon1, lat2, lon2):
        return None
    R = 6371
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    return R * 2 * atan2(sqrt(a), sqrt(1 - a))


def get_continent(lat, lon, zones_dict):
    for continent, zone in zones_dict.items():
        if all(k in zone for k in ['tl_y', 'tl_x', 'br_y', 'br_x']):
            if zone['br_y'] <= lat <= zone['tl_y'] and zone['tl_x'] <= lon <= zone['br_x']:
                return continent
    return None


def extract_flights():
    api = FlightRadar24API()

    logger.info(" Récupération des vols en cours...")
    flights = api.get_flights()
    logger.info(f" {len(flights)} vols récupérés.")

    logger.info(" Récupération des IATA pour enrichissement...")
    iata_codes = set()
    for f in flights:
        if f.origin_airport_iata:
            iata_codes.add(f.origin_airport_iata)
        if f.destination_airport_iata:
            iata_codes.add(f.destination_airport_iata)

    logger.info(f"🔍 {len(iata_codes)} codes IATA collectés. Enrichissement des aéroports...")
    airport_info = {}
    for code in list(iata_codes):
        try:
            a = api.get_airport(code)
            airport_info[code] = {
                "iata": code,
                "latitude": a.latitude,
                "longitude": a.longitude,
                "name": a.name,
                "country": a.country,
            }
        except Exception:
            continue

    logger.info(f" {len(airport_info)} aéroports enrichis.")

    logger.info(" Chargement des zones géographiques...")
    zones = api.get_zones()

    logger.info(" Construction du DataFrame enrichi...")
    enriched_flights = []

    for f in flights:
        origin = airport_info.get(f.origin_airport_iata)
        dest = airport_info.get(f.destination_airport_iata)

        if not origin or not dest:
            continue

        origin_continent = get_continent(origin["latitude"], origin["longitude"], zones)
        dest_continent = get_continent(dest["latitude"], dest["longitude"], zones)

        distance_km = haversine(
            origin["latitude"], origin["longitude"],
            dest["latitude"], dest["longitude"]
        )

        enriched_flights.append({
            "flight_id": f.id,
            "callsign": f.callsign,
            "airline_icao": f.airline_icao,
            "origin_iata": f.origin_airport_iata,
            "dest_iata": f.destination_airport_iata,
            "origin_country": origin["country"],
            "dest_country": dest["country"],
            "origin_continent": origin_continent,
            "dest_continent": dest_continent,
            "distance_km": distance_km,
            "aircraft_code": f.aircraft_code,
            "registration": f.registration,
        })

    df = pd.DataFrame(enriched_flights)
    logger.info(f" DataFrame final contenant {len(df)} lignes.")

    return df

# %%
df = extract_flights()
df.head()
# Out:
#   flight_id callsign airline_icao origin_iata dest_iata origin_country  \
# 0  3b48565c  ARG1141          ARG         FCO       EZE          Italy
# 1  3b48b4e9   DAL201          DAL         JNB       ATL   South Africa
# 2  3b48c263   AIC186          AIC         YVR       DEL         Canada
# 3  3b48e840   AIC119          AIC         BOM       JFK          India
# 4  3b48f27a   AIC105          AIC         DEL       EWR          India
#
#     dest_country origin_continent dest_continent   distance_km aircraft_code  \
# 0      Argentina           europe   southamerica  11155.832877          A332
# 1  United States           africa   northamerica  13582.574536          A359
# 2          India     northamerica           asia  11137.280992          B77W
# 3  United States             asia   northamerica  12532.259844          B77W
# 4  United States             asia   northamerica  11763.730790          A359
#
#   registration
# 0       LV-FVH
# 1       N523DN
# 2       VT-ALO
# 3       VT-AEO
# 4       VT-JRE

# %% [markdown]
# |   | Indicateur                                                  | Colonnes utilisées                                                                                              | Source (fonction de l’API)                                                                                            |
# | --: | ----------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------- |
# | 1️⃣ | **Compagnie avec le plus de vols en cours**                 | `airline_icao`                                                                                                  | `get_flights()`                                                                                                       |
# | 2️⃣ | **Par continent, compagnie avec le plus de vols régionaux** | `airline_icao`, `origin_airport_iata`, `destination_airport_iata`, `origin_continent`, `destination_continent`  | `get_flights()` + `get_airport()` (pour lat/lon) + `get_zones()` (pour continents)                                    |
# | 3️⃣ | **Vol avec le trajet le plus long**                         | `origin_airport_iata`, `destination_airport_iata`, `distance_km` (calculée à partir de `latitude`, `longitude`) | `get_flights()` + `get_airport()` (pour coordonnées)                                                                  |
# | 4️⃣ | **Distance moyenne par continent**                          | `origin_continent`, `distance_km`                                                                               | `get_flights()` + `get_airport()` + `get_zones()`                                                                     |
# | 5️⃣ | **Constructeur avion avec le plus de vols actifs**          | `registration` → enrichissement via `aircraft.manufacturer` ou `equip`                                          | 🔴 Non exploitable : `get_flight_details()` ne fournit pas `manufacturer`, `search()` renvoie `equip` mais pas fiable |
# | 6️⃣ | **Top 3 modèles d’avion par pays de la compagnie**          | `airline_icao`, `aircraft_code`, `registration` + `country` (via `get_airlines()`)                              | 🟡 Partiel : `get_flights()` (codes) + `get_airlines()` (pays) ; pas de "vrai modèle" sans mapping externe            |

# %% [markdown]
# --> let's do some data exploration to understand our data, so that we can do the data cleaning

# %% [markdown]
# ### EDA( exploration data analysis )

# %%
print("Columns \n",df.columns)
# Out:
# Columns
#  Index(['flight_id', 'callsign', 'airline_icao', 'origin_iata', 'dest_iata',
#        'origin_country', 'dest_country', 'origin_continent', 'dest_continent',
#        'distance_km', 'aircraft_code', 'registration'],
#       dtype='object')

# %%
print("types \n", df.dtypes)
# Out:
# types
#  flight_id            object
# callsign             object
# airline_icao         object
# origin_iata          object
# dest_iata            object
# origin_country       object
# dest_country         object
# origin_continent     object
# dest_continent       object
# distance_km         float64
# aircraft_code        object
# registration         object
# dtype: object

# %%
# shape
df.shape
# Out:
# (1299, 12)

# %%
# Valeurs uniques
print("Valeurs unique \n",df.nunique().sort_values(ascending=False))
# Out:
# Valeurs unique
#  flight_id           1299
# callsign            1299
# registration        1299
# distance_km          994
# dest_iata            253
# origin_iata          244
# airline_icao         182
# dest_country         105
# origin_country        87
# aircraft_code         52
# dest_continent         8
# origin_continent       7
# dtype: int64

# %%
# check for Duplicates for id

print("duplicates \n",df.duplicated(subset=['flight_id']).sum())
# Out:
# duplicates
#  0

# %%
# Statistiques descriptives

print("Statistiques descriptives \n", df.describe(include='all'))
# Out:
# Statistiques descriptives
#         flight_id callsign airline_icao origin_iata dest_iata origin_country  \
# count       1299     1299         1299        1299      1299           1299
# unique      1299     1299          182         244       253             87
# top     3b4a8903   AVA229          QTR         DOH       LHR  United States
# freq           1        1           99          77        77            373
# mean         NaN      NaN          NaN         NaN       NaN            NaN
# std          NaN      NaN          NaN         NaN       NaN            NaN
# min          NaN      NaN          NaN         NaN       NaN            NaN
# 25%          NaN      NaN          NaN         NaN       NaN            NaN
# 50%          NaN      NaN          NaN         NaN       NaN            NaN
# 75%          NaN      NaN          NaN         NaN       NaN            NaN
# max          NaN      NaN          NaN         NaN       NaN            NaN
#
#          dest_country origin_continent dest_continent   distance_km  \
# count            1299             1296           1297   1299.000000
# unique            105                7              8           NaN
# top     United States             asia         europe           NaN
# freq              288              467            461           NaN
# mean              NaN              NaN            NaN   7206.260277
# std               NaN              NaN            NaN   3055.662597
# min               NaN              NaN            NaN      0.000000
# 25%               NaN              NaN            NaN   4595.239025
# 50%               NaN              NaN            NaN   7137.535196
# 75%               NaN              NaN            NaN   9372.667187
# max               NaN              NaN            NaN  15340.566113
#
#        aircraft_code registration
# count           1299         1299
# unique            52         1299
# top             B77W       N784AV
# freq             191            1
# mean             NaN          NaN
# std              NaN          NaN
# min              NaN          NaN
# 25%              NaN          NaN
# 50%              NaN          NaN
# 75%              NaN          NaN
# max              NaN          NaN

# %% [markdown]
# --> IL faut commentez

# %%
## Répartition des compagnies

# %%
print("Répartition des compagnies   \n", df["airline_icao"].value_counts().head(10))
# Out:
# Répartition des compagnies
#  airline_icao
# QTR    99
# UAE    82
# UAL    65
# AAL    62
# DAL    44
# THY    40
# BAW    26
# CES    26
# KAL    25
# AFR    25
# Name: count, dtype: int64

# %%
# Répartition des origines :

# %%
df["dest_country"].value_counts().head(10)

print("Répartition des origines   \n", df["origin_country"].value_counts().head(10))
# Out:
# Répartition des origines
#  origin_country
# United States           373
# China                    93
# United Arab Emirates     93
# Qatar                    78
# Australia                57
# Japan                    50
# South Korea              45
# Brazil                   33
# Hong Kong                24
# Russia                   24
# Name: count, dtype: int64

# %%
# Répartition des destinations :

print("Répartition des destinations   \n", df["dest_iata"].value_counts().head(10))
# Out:
# Répartition des destinations
#  dest_iata
# LHR    77
# JFK    45
# LAX    39
# CDG    38
# FRA    34
# DOH    29
# ICN    28
# SVO    27
# IST    26
# MAD    26
# Name: count, dtype: int64

# %% [markdown]
# --> To sum Up about our Data :
#
#     # callsign, airline_iata, airline_icao : pour identifier les compagnies
#
#     # aircraft_code, registration, squawk : pour identifier les avions
#
#     # latitude, longitude, altitude : position
#
#     # origin, destination : codes IATA
#
#     # ground_speed, heading, vertical_speed, on_ground : pour l'état du vol
#
#     # time : timestamp (en secondes POSIX, à convertir si besoin)

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Data Cleaning

# %%
# Valeurs manquantes
missing_values = (df.isna().sum() + (df == "").sum()).sort_values(ascending=False)
print("Valeurs manquantes (en nombre) \n", missing_values)
# Out:
# Valeurs manquantes (en nombre)
#  airline_icao        24
# origin_continent     3
# dest_continent       2
# callsign             1
# registration         1
# flight_id            0
# origin_iata          0
# dest_iata            0
# dest_country         0
# origin_country       0
# distance_km          0
# aircraft_code        0
# dtype: int64

# %%
# Pourcentage de valeurs manquantes, correctement affiché en %
missing_percent = ((df.isna().sum() + (df == "").sum()) / len(df) * 100).sort_values(ascending=False)
print("Valeurs manquantes en % :\n", missing_percent.round(2))
# Out:
# Valeurs manquantes en % :
#  airline_icao        1.85
# origin_continent    0.23
# dest_continent      0.15
# callsign            0.08
# registration        0.08
# flight_id           0.00
# origin_iata         0.00
# dest_iata           0.00
# dest_country        0.00
# origin_country      0.00
# distance_km         0.00
# aircraft_code       0.00
# dtype: float64

# %%
import pandas as pd
import logging

logger = logging.getLogger(__name__)

def clean_flights_data(df: pd.DataFrame) -> pd.DataFrame:
    logger.info("Nettoyage des données de vol...")

    # Étape 1 : Supprimer les colonnes avec + de 50% de valeurs manquantes
    missing_ratio = (df.isna().sum() + (df == "").sum()) / len(df)
    cols_to_drop = missing_ratio[missing_ratio > 0.5].index.tolist()
    if cols_to_drop:
        logger.info(f"Colonnes supprimées (plus de 50% de valeurs manquantes) : {cols_to_drop}")
        df = df.drop(columns=cols_to_drop)

    # Étape 2 : Supprimer les lignes avec au moins une valeur manquante ou vide
    initial_row_count = len(df)
    df = df[~(df.isna() | (df == "")).any(axis=1)]
    removed_rows = initial_row_count - len(df)
    logger.info(f"Lignes supprimées pour valeurs manquantes : {removed_rows}")

    logger.info("Nettoyage terminé.")
    return df

# %%
df_cleaned = clean_flights_data(df)

# %%
# Pourcentage de valeurs manquantes, correctement affiché en %
missing_percent = ((df_cleaned.isna().sum() + (df_cleaned == "").sum()) / len(df_cleaned) * 100).sort_values(ascending=False)
print("Valeurs manquantes en % après le cleaning :\n", missing_percent.round(2))
# Out:
# Valeurs manquantes en % après le cleaning :
#  flight_id           0.0
# callsign            0.0
# airline_icao        0.0
# origin_iata         0.0
# dest_iata           0.0
# origin_country      0.0
# dest_country        0.0
# origin_continent    0.0
# dest_continent      0.0
# distance_km         0.0
# aircraft_code       0.0
# registration        0.0
# dtype: float64

# %% [markdown]
# --> No missing data

# %% [markdown]
# ## Load Data into CSV format ( Or parquet )

# %%
import os
from datetime import datetime, timezone
import pandas as pd

def save_to_csv(df: pd.DataFrame, base_path="Flights/rawzone") -> str:
    """
    Sauvegarde le DataFrame au format CSV avec une nomenclature horodatée.
    Exemple de chemin : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-13/flights_20250713124500.csv
    """
    now = datetime.now(timezone.utc)

    # Création du chemin horodaté
    path = os.path.join(
        base_path,
        f"tech_year={now.year}",
        f"tech_month={now.strftime('%Y-%m')}",
        f"tech_day={now.strftime('%Y-%m-%d')}"
    )
    os.makedirs(path, exist_ok=True)

    # Nom du fichier CSV
    filename = f"flights_{now.strftime('%Y%m%d%H%M%S')}.csv"
    full_path = os.path.join(path, filename)

    # Sauvegarde en CSV
    df.to_csv(full_path, index=False)
    print(f"[INFO] Fichier CSV sauvegardé : {full_path}")

    return full_path

# %%
df_cleaned = clean_flights_data(df)
save_to_csv(df_cleaned)
# Out:
# [INFO] Fichier CSV sauvegardé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717112538.csv
# 'Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717112538.csv'

# %% [markdown]
# ## Spark Analysis

# %%
def get_latest_csv_path(base_path="Flights/rawzone") -> str:
    """
    Parcourt récursivement les sous-dossiers pour trouver le fichier CSV le plus récent.
    """
    latest_time = None
    latest_file = None

    for root, _, files in os.walk(base_path):
        for file in files:
            if file.endswith(".csv"):
                full_path = os.path.join(root, file)
                file_time = os.path.getmtime(full_path)
                if not latest_time or file_time > latest_time:
                    latest_time = file_time
                    latest_file = full_path

    if latest_file:
        print(f"[INFO] Dernier fichier CSV trouvé : {latest_file}")
        return latest_file
    else:
        raise FileNotFoundError("Aucun fichier CSV trouvé dans le répertoire.")

# %%
# spark_analysis.py

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, count, desc, row_number, when
from pyspark.sql.window import Window

def run_spark_analysis():
    spark = SparkSession.builder.appName("FlightRadar24 Analysis").getOrCreate()

    csv_path = get_latest_csv_path()
    df = spark.read.option("header", True).option("inferSchema", True).csv(csv_path)
    df.cache()

    print(" Début de l’analyse Spark...\n")

    # -------------------------------
    # 1. Compagnie avec le plus de vols en cours
    # -------------------------------
    df1 = df.groupBy("airline_icao").agg(count("*").alias("nb_vols")).orderBy(desc("nb_vols"))
    top_airline = df1.limit(1)
    print("1. Compagnie avec le plus de vols en cours :")
    top_airline.show(truncate=False)

    # -------------------------------
    # 2. Compagnie avec le plus de vols régionaux par continent
    # -------------------------------
    regional_df = df.filter(
        (col("origin_continent").isNotNull()) &
        (col("dest_continent").isNotNull()) &
        (col("origin_continent") == col("dest_continent")) &
        (col("airline_icao").isNotNull()) &
        (col("airline_icao") != "")
    )

    regional_counts = regional_df.groupBy("origin_continent", "airline_icao") \
                                 .agg(count("*").alias("nb_vols"))

    region_window = Window.partitionBy("origin_continent").orderBy(desc("nb_vols"))
    top_regionals = regional_counts.withColumn("rank", row_number().over(region_window)) \
                                   .filter(col("rank") == 1) \
                                   .drop("rank")

    print("2. Compagnie avec le plus de vols régionaux par continent :")
    top_regionals.show(truncate=False)

    # -------------------------------
    # 3. Vol avec le trajet le plus long
    # -------------------------------
    longest_flight = df.filter(col("distance_km").isNotNull()) \
                       .orderBy(desc("distance_km")) \
                       .limit(1)

    print("3. Vol avec le trajet le plus long :")
    longest_flight.show(truncate=False)

    # -------------------------------
    # 4. Distance moyenne par continent
    # -------------------------------
    avg_distance = df.filter(col("distance_km").isNotNull()) \
                     .groupBy("origin_continent") \
                     .agg(avg("distance_km").alias("avg_distance_km")) \
                     .orderBy("origin_continent")

    print("4. Distance moyenne des vols par continent :")
    avg_distance.show(truncate=False)

    # -------------------------------
    # 5. Constructeur avec le plus de vols actifs
    # -------------------------------
    constructor_map = {
        "A3": "Airbus", "A2": "Airbus",
        "B7": "Boeing", "B8": "Boeing",
        "E1": "Embraer", "E2": "Embraer", "EMB": "Embraer",
        "CRJ": "Bombardier", "C": "Bombardier", "DH": "Bombardier",
        "AT": "ATR",
        "DC": "McDonnell Douglas", "MD": "McDonnell Douglas",
        "G": "Gulfstream", "F": "Dassault",
        "C5": "Cessna", "C6": "Cessna",
        "SU": "Sukhoi", "C9": "COMAC", "MRJ": "Mitsubishi",
        "TU": "Tupolev", "IL": "Ilyushin", "AN": "Antonov"
    }

    constructor_expr = None
    for prefix, name in constructor_map.items():
        condition = col("aircraft_code").startswith(prefix)
        constructor_expr = when(condition, name) if constructor_expr is None else constructor_expr.when(condition, name)
    constructor_expr = constructor_expr.otherwise("Inconnu")

    df = df.withColumn("constructeur", constructor_expr)

    constructeur_top = df.groupBy("constructeur").count().orderBy(col("count").desc()).limit(1)

    print("5. Constructeur avec le plus de vols actifs :")
    constructeur_top.show(truncate=False)

    # -------------------------------
    # 6. Top 3 modèles d’avion par pays de la compagnie
    # -------------------------------
    if "origin_country" in df.columns and "aircraft_code" in df.columns:
        model_counts = df.filter(
            col("origin_country").isNotNull() & col("aircraft_code").isNotNull()
        ).groupBy("origin_country", "aircraft_code") \
         .agg(count("*").alias("nb_vols"))

        window = Window.partitionBy("origin_country").orderBy(desc("nb_vols"))
        top_models = model_counts.withColumn("rank", row_number().over(window)) \
                                 .filter(col("rank") <= 3) \
                                 .select("origin_country", "aircraft_code", "nb_vols", "rank") \
                                 .orderBy("origin_country", "rank")

        print("6. Top 3 modèles d’avion en usage par pays de compagnie :")
        top_models.show(100, truncate=False)
    else:
        print(" Colonnes nécessaires absentes pour KPI 6.")

    spark.stop()

# %%
run_spark_analysis()
# Out:
# [INFO] Dernier fichier CSV trouvé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717112538.csv
#  Début de l’analyse Spark...
#
# 1. Compagnie avec le plus de vols en cours :
# +------------+-------+
# |airline_icao|nb_vols|
# +------------+-------+
# |QTR         |99     |
# +------------+-------+
#
# 2. Compagnie avec le plus de vols régionaux par continent :
# +----------------+------------+-------+
# |origin_continent|airline_icao|nb_vols|
# +----------------+------------+-------+
# |africa          |ETH         |7      |
# |asia            |UAE         |6      |
# |europe          |EZY         |3      |
# |northamerica    |AAL         |38     |
# |oceania         |JST         |10     |
# |southamerica    |LAN         |2      |
# +----------------+------------+-------+
#
# 3. Vol avec le trajet le plus long :
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |flight_id|callsign|airline_icao|origin_iata|dest_iata|origin_country|dest_country|origin_continent|dest_continent|distance_km       |aircraft_code|registration|
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |3b49ed6d |SIA23   |SIA         |JFK        |SIN      |United States |Singapore   |northamerica    |oceania       |15340.566113064817|A359         |9V-SGF      |
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
#
# 4. Distance moyenne des vols par continent :
# +----------------+-----------------+
# |origin_continent|avg_distance_km  |
# +----------------+-----------------+
# |africa          |5881.273548839331|
# |asia            |7328.91156461502 |
# |europe          |6252.687844895627|
# |maldives        |6587.292753986953|
# |northamerica    |7539.809122655043|
# |oceania         |7542.242804896518|
# |southamerica    |7540.178191447533|
# +----------------+-----------------+
#
# 5. Constructeur avec le plus de vols actifs :
# +------------+-----+
# |constructeur|count|
# +------------+-----+
# |Boeing      |677  |
# +------------+-----+
#
# 6. Top 3 modèles d’avion en usage par pays de compagnie :
# +------------------+-------------+-------+----+
# |origin_country    |aircraft_code|nb_vols|rank|
# +------------------+-------------+-------+----+
# |Angola            |B38M         |1      |1   |
# |Argentina         |A332         |3      |1   |
# |Argentina         |B789         |2      |2   |
# |Argentina         |A319         |1      |3   |
# |Australia         |B789         |10     |1   |
# |Australia         |A359         |9      |2   |
# |Australia         |A333         |8      |3   |
# |Austria           |B77W         |1      |1   |
# |Azerbaijan        |B744         |1      |1   |
# |Azerbaijan        |B748         |1      |2   |
# |Bahrain           |A20N         |1      |1   |
# |Bahrain           |A333         |1      |2   |
# |Bangladesh        |B788         |2      |1   |
# |Belarus           |B738         |2      |1   |
# |Belgium           |B77L         |3      |1   |
# |Belgium           |B744         |2      |2   |
# |Belgium           |B763         |1      |3   |
# |Bolivia           |A332         |1      |1   |
# |Brazil            |B77W         |7      |1   |
# |Brazil            |B39M         |5      |2   |
# |Brazil            |B789         |5      |3   |
# |Canada            |B77W         |8      |1   |
# |Canada            |B789         |5      |2   |
# |Canada            |A359         |2      |3   |
# |Chile             |B789         |2      |1   |
# |Chile             |B788         |2      |2   |
# |Chile             |B39M         |1      |3   |
# |China             |B77W         |14     |1   |
# |China             |A332         |13     |2   |
# |China             |A359         |12     |3   |
# |Colombia          |B788         |3      |1   |
# |Colombia          |A320         |2      |2   |
# |Colombia          |A359         |2      |3   |
# |Costa Rica        |A359         |1      |1   |
# |Costa Rica        |B738         |1      |2   |
# |Cuba              |B789         |1      |1   |
# |Denmark           |B763         |1      |1   |
# |Denmark           |B77L         |1      |2   |
# |Dominican Republic|B38M         |1      |1   |
# |Dominican Republic|A320         |1      |2   |
# |Dominican Republic|BCS3         |1      |3   |
# |Ecuador           |A332         |1      |1   |
# |Egypt             |A20N         |2      |1   |
# |Egypt             |B738         |2      |2   |
# |Egypt             |B789         |2      |3   |
# |El Salvador       |A332         |1      |1   |
# |Ethiopia          |A359         |2      |1   |
# |Ethiopia          |B38M         |1      |2   |
# |Ethiopia          |B738         |1      |3   |
# |Fiji              |B38M         |1      |1   |
# |France            |B77L         |3      |1   |
# |France            |B77W         |3      |2   |
# |France            |B738         |2      |3   |
# |Georgia           |B738         |2      |1   |
# |Germany           |B77L         |6      |1   |
# |Germany           |B748         |2      |2   |
# |Germany           |B764         |1      |3   |
# |Ghana             |B38M         |1      |1   |
# |Greece            |B789         |1      |1   |
# |Greece            |A339         |1      |2   |
# |Guyana            |A21N         |1      |1   |
# |Honduras          |A359         |1      |1   |
# |Hong Kong         |B77W         |5      |1   |
# |Hong Kong         |A35K         |4      |2   |
# |Hong Kong         |B744         |4      |3   |
# |India             |B77L         |5      |1   |
# |India             |B772         |3      |2   |
# |India             |B789         |3      |3   |
# |Indonesia         |A21N         |3      |1   |
# |Indonesia         |B77W         |3      |2   |
# |Indonesia         |A333         |2      |3   |
# |Ireland           |C130         |1      |1   |
# |Ireland           |A320         |1      |2   |
# |Israel            |B789         |2      |1   |
# |Israel            |B788         |1      |2   |
# |Italy             |A359         |3      |1   |
# |Italy             |A333         |1      |2   |
# |Italy             |A339         |1      |3   |
# |Jamaica           |A339         |1      |1   |
# |Jamaica           |B772         |1      |2   |
# |Jamaica           |A333         |1      |3   |
# |Japan             |B77W         |9      |1   |
# |Japan             |B789         |9      |2   |
# |Japan             |A359         |5      |3   |
# |Jordan            |A20N         |2      |1   |
# |Jordan            |A332         |1      |2   |
# |Kazakhstan        |B763         |1      |1   |
# |Kazakhstan        |A21N         |1      |2   |
# |Kazakhstan        |A332         |1      |3   |
# |Kenya             |B788         |4      |1   |
# |Kenya             |B789         |1      |2   |
# |Kuwait            |B77W         |3      |1   |
# |Kuwait            |A339         |1      |2   |
# |Kuwait            |A20N         |1      |3   |
# |Lithuania         |E3TF         |1      |1   |
# |Luxembourg        |B748         |1      |1   |
# |Malaysia          |A333         |4      |1   |
# |Malaysia          |A21N         |1      |2   |
# |Malaysia          |B772         |1      |3   |
# |Maldives          |A359         |1      |1   |
# +------------------+-------------+-------+----+
# only showing top 100 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, desc, abs

spark = SparkSession.builder.appName("FlightRadar24 Analysis").getOrCreate()

# %%
# Adapter le path selon vtre notebook
df = spark.read.option("header", True).option("inferSchema", True).csv("/content/Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717104706.csv")

# -------------------------------
# BONUS : Aéroport avec le plus d’écart entre vols sortants et entrants
# -------------------------------
if "origin_iata" in df.columns and "dest_iata" in df.columns:

    outgoing = df.groupBy("origin_iata") \
                 .agg(count("*").alias("nb_sortants")) \
                 .withColumnRenamed("origin_iata", "iata")

    incoming = df.groupBy("dest_iata") \
                 .agg(count("*").alias("nb_entrants")) \
                 .withColumnRenamed("dest_iata", "iata")

    airport_diff = outgoing.join(incoming, on="iata", how="outer") \
                           .fillna(0) \
                           .withColumn("diff_abs", abs(col("nb_sortants") - col("nb_entrants")))

    top_diff = airport_diff.orderBy(desc("diff_abs")).limit(1)

    print(" BONUS : Aéroport avec la plus grande différence entre vols sortants et entrants :")
    top_diff.show(truncate=False)

else:
    print(" Colonnes 'origin_iata' ou 'dest_iata' manquantes dans le DataFrame.")
# Out:
#  BONUS : Aéroport avec la plus grande différence entre vols sortants et entrants :
# +----+-----------+-----------+--------+
# |iata|nb_sortants|nb_entrants|diff_abs|
# +----+-----------+-----------+--------+
# |LHR |1          |82         |81      |
# +----+-----------+-----------+--------+

# %% [markdown]
# ## Pipeline ETL

# %%
import logging
from datetime import datetime
import traceback

def run_pipeline():
    logger = logging.getLogger("FlightRadarETL")
    logging.basicConfig(level=logging.INFO)

    try:
        logger.info("🛫 Lancement du pipeline ETL FlightRadar24")

        # 1. Extraction

        logger.info("Extraction des données")

        df = extract_flights()

        # 2. Nettoyage
        logger.info(" Transformation des données en cours...")

        df_cleaned = clean_flights_data(df)

        # 3. Sauvegarde (CSV ou Parquet)
        path_saved = save_to_csv(df_cleaned)

        logger.info(f" Données sauvegardées dans : {path_saved}")

        # 4. Déclenchement de l’analyse Spark
        run_spark_analysis()

    except Exception as e:
        logger.error(f" Une erreur est survenue : {e}")
        traceback.print_exc()

# %% [markdown]
# ### Tester de la pipeline

# %%
run_pipeline()
# Out:
# [INFO] Fichier CSV sauvegardé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717113353.csv
# [INFO] Dernier fichier CSV trouvé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717113353.csv
#  Début de l’analyse Spark...
#
# 1. Compagnie avec le plus de vols en cours :
# +------------+-------+
# |airline_icao|nb_vols|
# +------------+-------+
# |QTR         |99     |
# +------------+-------+
#
# 2. Compagnie avec le plus de vols régionaux par continent :
# +----------------+------------+-------+
# |origin_continent|airline_icao|nb_vols|
# +----------------+------------+-------+
# |africa          |ETH         |6      |
# |asia            |UAE         |7      |
# |europe          |THY         |4      |
# |northamerica    |AAL         |35     |
# |oceania         |JST         |11     |
# |southamerica    |LAN         |2      |
# +----------------+------------+-------+
#
# 3. Vol avec le trajet le plus long :
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |flight_id|callsign|airline_icao|origin_iata|dest_iata|origin_country|dest_country|origin_continent|dest_continent|distance_km       |aircraft_code|registration|
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |3b49ed6d |SIA23   |SIA         |JFK        |SIN      |United States |Singapore   |northamerica    |oceania       |15340.566113064817|A359         |9V-SGF      |
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
#
# 4. Distance moyenne des vols par continent :
# +----------------+-----------------+
# |origin_continent|avg_distance_km  |
# +----------------+-----------------+
# |africa          |6029.558768598354|
# |asia            |7397.742146959319|
# |europe          |6072.769444757905|
# |maldives        |6587.292753986953|
# |northamerica    |7591.781713479204|
# |oceania         |7584.560331146176|
# |southamerica    |7641.978278601622|
# +----------------+-----------------+
#
# 5. Constructeur avec le plus de vols actifs :
# +------------+-----+
# |constructeur|count|
# +------------+-----+
# |Boeing      |676  |
# +------------+-----+
#
# 6. Top 3 modèles d’avion en usage par pays de compagnie :
# +------------------+-------------+-------+----+
# |origin_country    |aircraft_code|nb_vols|rank|
# +------------------+-------------+-------+----+
# |Angola            |B38M         |1      |1   |
# |Argentina         |A332         |2      |1   |
# |Argentina         |B789         |2      |2   |
# |Argentina         |A319         |1      |3   |
# |Australia         |B789         |10     |1   |
# |Australia         |A333         |9      |2   |
# |Australia         |A359         |7      |3   |
# |Austria           |B77W         |1      |1   |
# |Azerbaijan        |B744         |1      |1   |
# |Azerbaijan        |B748         |1      |2   |
# |Bahrain           |A333         |1      |1   |
# |Bangladesh        |B788         |2      |1   |
# |Belarus           |B738         |2      |1   |
# |Belgium           |B77L         |4      |1   |
# |Belgium           |B744         |2      |2   |
# |Belgium           |B763         |1      |3   |
# |Bolivia           |A332         |1      |1   |
# |Brazil            |B77W         |7      |1   |
# |Brazil            |B39M         |5      |2   |
# |Brazil            |B789         |5      |3   |
# |Canada            |B77W         |7      |1   |
# |Canada            |B789         |5      |2   |
# |Canada            |A359         |2      |3   |
# |Chile             |B789         |2      |1   |
# |Chile             |B788         |2      |2   |
# |Chile             |B39M         |1      |3   |
# |China             |B77W         |14     |1   |
# |China             |A359         |12     |2   |
# |China             |B77L         |11     |3   |
# |Colombia          |B788         |3      |1   |
# |Colombia          |A320         |2      |2   |
# |Colombia          |A359         |2      |3   |
# |Costa Rica        |A359         |1      |1   |
# |Costa Rica        |B738         |1      |2   |
# |Cuba              |B789         |1      |1   |
# |Denmark           |B763         |1      |1   |
# |Denmark           |B77L         |1      |2   |
# |Dominican Republic|B38M         |1      |1   |
# |Dominican Republic|A320         |1      |2   |
# |Dominican Republic|BCS3         |1      |3   |
# |Ecuador           |A332         |1      |1   |
# |Egypt             |B738         |3      |1   |
# |Egypt             |A20N         |2      |2   |
# |Egypt             |B39M         |1      |3   |
# |El Salvador       |A332         |1      |1   |
# |Ethiopia          |B38M         |1      |1   |
# |Ethiopia          |B788         |1      |2   |
# |Ethiopia          |B789         |1      |3   |
# |Fiji              |B38M         |1      |1   |
# |France            |B77L         |3      |1   |
# |France            |B77W         |3      |2   |
# |France            |A21N         |2      |3   |
# |Georgia           |B763         |1      |1   |
# |Georgia           |B738         |1      |2   |
# |Germany           |B77L         |6      |1   |
# |Germany           |B748         |2      |2   |
# |Germany           |B764         |1      |3   |
# |Ghana             |B38M         |1      |1   |
# |Greece            |B789         |1      |1   |
# |Greece            |A339         |1      |2   |
# |Guyana            |A21N         |1      |1   |
# |Honduras          |A359         |1      |1   |
# |Hong Kong         |B77W         |6      |1   |
# |Hong Kong         |A35K         |4      |2   |
# |Hong Kong         |B744         |4      |3   |
# |India             |B77L         |5      |1   |
# |India             |B772         |3      |2   |
# |India             |B789         |3      |3   |
# |Indonesia         |B77W         |4      |1   |
# |Indonesia         |A333         |2      |2   |
# |Indonesia         |A21N         |2      |3   |
# |Ireland           |C130         |1      |1   |
# |Ireland           |B789         |1      |2   |
# |Israel            |B789         |2      |1   |
# |Israel            |B788         |1      |2   |
# |Italy             |A359         |3      |1   |
# |Italy             |A339         |2      |2   |
# |Italy             |A333         |1      |3   |
# |Jamaica           |A339         |1      |1   |
# |Jamaica           |B772         |1      |2   |
# |Jamaica           |A333         |1      |3   |
# |Japan             |B77W         |9      |1   |
# |Japan             |B789         |9      |2   |
# |Japan             |A359         |5      |3   |
# |Jordan            |A20N         |2      |1   |
# |Jordan            |A332         |1      |2   |
# |Kazakhstan        |B763         |1      |1   |
# |Kazakhstan        |A21N         |1      |2   |
# |Kazakhstan        |A332         |1      |3   |
# |Kenya             |B788         |4      |1   |
# |Kenya             |B789         |1      |2   |
# |Kuwait            |B77W         |2      |1   |
# |Kuwait            |A20N         |1      |2   |
# |Lithuania         |E3TF         |1      |1   |
# |Luxembourg        |B748         |1      |1   |
# |Malaysia          |A333         |3      |1   |
# |Malaysia          |A21N         |1      |2   |
# |Malaysia          |B772         |1      |3   |
# |Maldives          |A359         |1      |1   |
# |Mexico            |A359         |5      |1   |
# +------------------+-------------+-------+----+
# only showing top 100 rows

# %% [markdown]
# ## Lancement du Cronjonb à fréquence de 2 min pour tester

# %%
import time
import logging
import traceback
from datetime import datetime

log_file = "pipeline.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger("FlightRadarETL")

def run_pipeline_job():
    logger.info(" Lancement du job ETL")
    print("\n Lancement du job ETL...")

    try:
        run_pipeline()
        logger.info("Pipeline terminé avec succès.")
        print(" Pipeline terminé avec succès.")
    except Exception as e:
        logger.error(f" Erreur dans le pipeline : {e}")
        logger.error(traceback.format_exc())
        print(f" Erreur dans le pipeline : {e}")

# Boucle de test : exécuter toutes les 2 minutes
for i in range(3):
    print(f"\n=========== 🔄 Lancement #{i+1} à {datetime.now().strftime('%H:%M:%S')} ===========")
    run_pipeline_job()
    print("\n ")
    print(f"[🕒] Prochain lancement dans 2 minutes...\n")
    time.sleep(2 * 60)
# Out:
# =========== 🔄 Lancement #1 à 11:33:57 ===========
#
#  Lancement du job ETL...
# [INFO] Fichier CSV sauvegardé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717113619.csv
# [INFO] Dernier fichier CSV trouvé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717113619.csv
#  Début de l’analyse Spark...
#
# 1. Compagnie avec le plus de vols en cours :
# +------------+-------+
# |airline_icao|nb_vols|
# +------------+-------+
# |QTR         |99     |
# +------------+-------+
#
# 2. Compagnie avec le plus de vols régionaux par continent :
# +----------------+------------+-------+
# |origin_continent|airline_icao|nb_vols|
# +----------------+------------+-------+
# |africa          |ETH         |5      |
# |asia            |UAE         |7      |
# |europe          |THY         |3      |
# |northamerica    |AAL         |33     |
# |oceania         |JST         |10     |
# |southamerica    |LAN         |2      |
# +----------------+------------+-------+
#
# 3. Vol avec le trajet le plus long :
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |flight_id|callsign|airline_icao|origin_iata|dest_iata|origin_country|dest_country|origin_continent|dest_continent|distance_km       |aircraft_code|registration|
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |3b49ed6d |SIA23   |SIA         |JFK        |SIN      |United States |Singapore   |northamerica    |oceania       |15340.566113064817|A359         |9V-SGF      |
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
#
# 4. Distance moyenne des vols par continent :
# +----------------+-----------------+
# |origin_continent|avg_distance_km  |
# +----------------+-----------------+
# |africa          |6006.073748906422|
# |asia            |7411.330785415957|
# |europe          |6260.42057069079 |
# |maldives        |6587.292753986953|
# |northamerica    |7651.493582346564|
# |oceania         |7513.781155128323|
# |southamerica    |7687.491861934822|
# +----------------+-----------------+
#
# 5. Constructeur avec le plus de vols actifs :
# +------------+-----+
# |constructeur|count|
# +------------+-----+
# |Boeing      |672  |
# +------------+-----+
#
# 6. Top 3 modèles d’avion en usage par pays de compagnie :
# +------------------+-------------+-------+----+
# |origin_country    |aircraft_code|nb_vols|rank|
# +------------------+-------------+-------+----+
# |Angola            |B38M         |1      |1   |
# |Argentina         |A332         |2      |1   |
# |Argentina         |B789         |2      |2   |
# |Argentina         |A319         |1      |3   |
# |Australia         |B789         |10     |1   |
# |Australia         |A333         |9      |2   |
# |Australia         |A359         |7      |3   |
# |Austria           |B77W         |1      |1   |
# |Azerbaijan        |B744         |1      |1   |
# |Azerbaijan        |B748         |1      |2   |
# |Bahrain           |A333         |1      |1   |
# |Bangladesh        |B788         |2      |1   |
# |Belarus           |B738         |2      |1   |
# |Belgium           |B77L         |4      |1   |
# |Belgium           |B744         |2      |2   |
# |Belgium           |B763         |1      |3   |
# |Bolivia           |A332         |1      |1   |
# |Brazil            |B77W         |7      |1   |
# |Brazil            |B789         |5      |2   |
# |Brazil            |B39M         |4      |3   |
# |Canada            |B77W         |7      |1   |
# |Canada            |B789         |5      |2   |
# |Canada            |A359         |2      |3   |
# |Chile             |B789         |2      |1   |
# |Chile             |B788         |2      |2   |
# |Chile             |B39M         |1      |3   |
# |China             |B77W         |14     |1   |
# |China             |A359         |12     |2   |
# |China             |B77L         |11     |3   |
# |Colombia          |B788         |3      |1   |
# |Colombia          |A320         |2      |2   |
# |Colombia          |A359         |2      |3   |
# |Costa Rica        |A359         |1      |1   |
# |Costa Rica        |B738         |1      |2   |
# |Cuba              |B789         |1      |1   |
# |Denmark           |B763         |2      |1   |
# |Denmark           |B77L         |1      |2   |
# |Dominican Republic|B38M         |1      |1   |
# |Dominican Republic|A320         |1      |2   |
# |Dominican Republic|BCS3         |1      |3   |
# |Ecuador           |A332         |1      |1   |
# |Egypt             |B738         |3      |1   |
# |Egypt             |A20N         |2      |2   |
# |Egypt             |B39M         |1      |3   |
# |El Salvador       |A332         |1      |1   |
# |Ethiopia          |B38M         |1      |1   |
# |Ethiopia          |B788         |1      |2   |
# |Ethiopia          |B789         |1      |3   |
# |Fiji              |B38M         |1      |1   |
# |France            |B77L         |3      |1   |
# |France            |B77W         |3      |2   |
# |France            |B738         |2      |3   |
# |Georgia           |B763         |1      |1   |
# |Georgia           |B738         |1      |2   |
# |Germany           |B77L         |6      |1   |
# |Germany           |B764         |2      |2   |
# |Germany           |B748         |2      |3   |
# |Ghana             |B38M         |1      |1   |
# |Greece            |B789         |1      |1   |
# |Greece            |A339         |1      |2   |
# |Guam              |B773         |1      |1   |
# |Guyana            |A21N         |1      |1   |
# |Honduras          |A359         |1      |1   |
# |Hong Kong         |B77W         |5      |1   |
# |Hong Kong         |A35K         |4      |2   |
# |Hong Kong         |B744         |4      |3   |
# |India             |B77L         |5      |1   |
# |India             |B772         |3      |2   |
# |India             |B789         |3      |3   |
# |Indonesia         |B77W         |4      |1   |
# |Indonesia         |A333         |3      |2   |
# |Indonesia         |A21N         |2      |3   |
# |Ireland           |C130         |1      |1   |
# |Ireland           |B789         |1      |2   |
# |Israel            |B789         |2      |1   |
# |Israel            |B788         |1      |2   |
# |Italy             |A359         |3      |1   |
# |Italy             |A339         |2      |2   |
# |Italy             |A333         |1      |3   |
# |Jamaica           |A339         |1      |1   |
# |Jamaica           |B772         |1      |2   |
# |Jamaica           |A333         |1      |3   |
# |Japan             |B77W         |9      |1   |
# |Japan             |B789         |9      |2   |
# |Japan             |B788         |6      |3   |
# |Jordan            |A20N         |2      |1   |
# |Jordan            |A332         |1      |2   |
# |Kazakhstan        |B763         |1      |1   |
# |Kazakhstan        |A21N         |1      |2   |
# |Kazakhstan        |A332         |1      |3   |
# |Kenya             |B788         |4      |1   |
# |Kenya             |B789         |1      |2   |
# |Kuwait            |B77W         |2      |1   |
# |Kuwait            |A20N         |1      |2   |
# |Lithuania         |E3TF         |1      |1   |
# |Luxembourg        |B748         |1      |1   |
# |Malaysia          |A333         |3      |1   |
# |Malaysia          |A21N         |1      |2   |
# |Malaysia          |B772         |1      |3   |
# |Maldives          |A359         |1      |1   |
# +------------------+-------------+-------+----+
# only showing top 100 rows
#
#  Pipeline terminé avec succès.
#
#
# [🕒] Prochain lancement dans 2 minutes...
#
#
# =========== 🔄 Lancement #2 à 11:38:23 ===========
#
#  Lancement du job ETL...
# [INFO] Fichier CSV sauvegardé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717114052.csv
# [INFO] Dernier fichier CSV trouvé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717114052.csv
#  Début de l’analyse Spark...
#
# 1. Compagnie avec le plus de vols en cours :
# +------------+-------+
# |airline_icao|nb_vols|
# +------------+-------+
# |QTR         |103    |
# +------------+-------+
#
# 2. Compagnie avec le plus de vols régionaux par continent :
# +----------------+------------+-------+
# |origin_continent|airline_icao|nb_vols|
# +----------------+------------+-------+
# |africa          |ETH         |5      |
# |asia            |UAE         |7      |
# |europe          |THY         |2      |
# |northamerica    |AAL         |30     |
# |oceania         |JST         |10     |
# |southamerica    |LAN         |2      |
# +----------------+------------+-------+
#
# 3. Vol avec le trajet le plus long :
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |flight_id|callsign|airline_icao|origin_iata|dest_iata|origin_country|dest_country|origin_continent|dest_continent|distance_km       |aircraft_code|registration|
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |3b49ed6d |SIA23   |SIA         |JFK        |SIN      |United States |Singapore   |northamerica    |oceania       |15340.566113064817|A359         |9V-SGF      |
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
#
# 4. Distance moyenne des vols par continent :
# +----------------+------------------+
# |origin_continent|avg_distance_km   |
# +----------------+------------------+
# |africa          |5801.740340637489 |
# |asia            |7429.688526137494 |
# |europe          |6263.694363194978 |
# |maldives        |4873.383191789104 |
# |northamerica    |7751.9914404539795|
# |oceania         |7554.85370128749  |
# |southamerica    |7693.596783006156 |
# +----------------+------------------+
#
# 5. Constructeur avec le plus de vols actifs :
# +------------+-----+
# |constructeur|count|
# +------------+-----+
# |Boeing      |669  |
# +------------+-----+
#
# 6. Top 3 modèles d’avion en usage par pays de compagnie :
# +------------------+-------------+-------+----+
# |origin_country    |aircraft_code|nb_vols|rank|
# +------------------+-------------+-------+----+
# |Angola            |B38M         |1      |1   |
# |Argentina         |A332         |2      |1   |
# |Argentina         |B789         |2      |2   |
# |Argentina         |A319         |1      |3   |
# |Australia         |B789         |9      |1   |
# |Australia         |A333         |9      |2   |
# |Australia         |A359         |6      |3   |
# |Austria           |B77W         |1      |1   |
# |Austria           |A321         |1      |2   |
# |Azerbaijan        |B744         |1      |1   |
# |Azerbaijan        |B748         |1      |2   |
# |Bahrain           |A333         |1      |1   |
# |Bangladesh        |B788         |2      |1   |
# |Belarus           |B738         |2      |1   |
# |Belgium           |B77L         |5      |1   |
# |Belgium           |B744         |2      |2   |
# |Belgium           |B752         |1      |3   |
# |Bolivia           |A332         |1      |1   |
# |Brazil            |B77W         |6      |1   |
# |Brazil            |B789         |5      |2   |
# |Brazil            |B39M         |4      |3   |
# |Canada            |B77W         |7      |1   |
# |Canada            |B789         |5      |2   |
# |Canada            |B77L         |2      |3   |
# |Chile             |B789         |2      |1   |
# |Chile             |B788         |2      |2   |
# |Chile             |B39M         |1      |3   |
# |China             |B77W         |14     |1   |
# |China             |A359         |12     |2   |
# |China             |B77L         |11     |3   |
# |Colombia          |B788         |3      |1   |
# |Colombia          |A359         |2      |2   |
# |Colombia          |A320         |1      |3   |
# |Costa Rica        |A359         |1      |1   |
# |Costa Rica        |B738         |1      |2   |
# |Cuba              |B789         |1      |1   |
# |Denmark           |B763         |2      |1   |
# |Denmark           |B788         |1      |2   |
# |Denmark           |B77L         |1      |3   |
# |Dominican Republic|B38M         |1      |1   |
# |Dominican Republic|A320         |1      |2   |
# |Dominican Republic|BCS3         |1      |3   |
# |Ecuador           |A332         |1      |1   |
# |Egypt             |B738         |3      |1   |
# |Egypt             |A20N         |2      |2   |
# |Egypt             |B39M         |1      |3   |
# |El Salvador       |A332         |1      |1   |
# |Ethiopia          |B38M         |1      |1   |
# |Ethiopia          |B788         |1      |2   |
# |Ethiopia          |B789         |1      |3   |
# |Fiji              |B38M         |1      |1   |
# |France            |B77L         |3      |1   |
# |France            |B77W         |3      |2   |
# |France            |B738         |2      |3   |
# |Georgia           |B738         |1      |1   |
# |Germany           |B77L         |6      |1   |
# |Germany           |B764         |2      |2   |
# |Germany           |B748         |2      |3   |
# |Ghana             |B38M         |1      |1   |
# |Greece            |B789         |1      |1   |
# |Greece            |A339         |1      |2   |
# |Guam              |B773         |1      |1   |
# |Guyana            |A21N         |1      |1   |
# |Honduras          |A359         |1      |1   |
# |Hong Kong         |B77W         |5      |1   |
# |Hong Kong         |A35K         |4      |2   |
# |Hong Kong         |B744         |4      |3   |
# |India             |B77L         |5      |1   |
# |India             |B763         |3      |2   |
# |India             |B789         |3      |3   |
# |Indonesia         |B77W         |5      |1   |
# |Indonesia         |A333         |3      |2   |
# |Indonesia         |A21N         |2      |3   |
# |Iran              |RJ85         |1      |1   |
# |Ireland           |C130         |1      |1   |
# |Ireland           |B789         |1      |2   |
# |Israel            |B789         |2      |1   |
# |Israel            |B788         |1      |2   |
# |Italy             |A359         |3      |1   |
# |Italy             |A339         |2      |2   |
# |Italy             |B38M         |2      |3   |
# |Jamaica           |A339         |1      |1   |
# |Jamaica           |B772         |1      |2   |
# |Jamaica           |A333         |1      |3   |
# |Japan             |B77W         |9      |1   |
# |Japan             |B789         |9      |2   |
# |Japan             |B788         |6      |3   |
# |Jordan            |A20N         |2      |1   |
# |Jordan            |A332         |1      |2   |
# |Kazakhstan        |B763         |1      |1   |
# |Kazakhstan        |A21N         |1      |2   |
# |Kazakhstan        |A332         |1      |3   |
# |Kenya             |B788         |4      |1   |
# |Kenya             |B789         |1      |2   |
# |Kuwait            |B77W         |2      |1   |
# |Kuwait            |A20N         |1      |2   |
# |Lithuania         |E3TF         |1      |1   |
# |Luxembourg        |B748         |2      |1   |
# |Malaysia          |A333         |3      |1   |
# |Malaysia          |A21N         |1      |2   |
# +------------------+-------------+-------+----+
# only showing top 100 rows
#
#  Pipeline terminé avec succès.
#
#
# [🕒] Prochain lancement dans 2 minutes...
#
#
# =========== 🔄 Lancement #3 à 11:42:56 ===========
#
#  Lancement du job ETL...
# [INFO] Fichier CSV sauvegardé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717114525.csv
# [INFO] Dernier fichier CSV trouvé : Flights/rawzone/tech_year=2025/tech_month=2025-07/tech_day=2025-07-17/flights_20250717114525.csv
#  Début de l’analyse Spark...
#
# 1. Compagnie avec le plus de vols en cours :
# +------------+-------+
# |airline_icao|nb_vols|
# +------------+-------+
# |QTR         |102    |
# +------------+-------+
#
# 2. Compagnie avec le plus de vols régionaux par continent :
# +----------------+------------+-------+
# |origin_continent|airline_icao|nb_vols|
# +----------------+------------+-------+
# |africa          |ETH         |3      |
# |asia            |UAE         |7      |
# |europe          |PGT         |2      |
# |northamerica    |AAL         |33     |
# |oceania         |JST         |10     |
# |southamerica    |LAN         |2      |
# +----------------+------------+-------+
#
# 3. Vol avec le trajet le plus long :
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |flight_id|callsign|airline_icao|origin_iata|dest_iata|origin_country|dest_country|origin_continent|dest_continent|distance_km       |aircraft_code|registration|
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
# |3b49ed6d |SIA23   |SIA         |JFK        |SIN      |United States |Singapore   |northamerica    |oceania       |15340.566113064817|A359         |9V-SGF      |
# +---------+--------+------------+-----------+---------+--------------+------------+----------------+--------------+------------------+-------------+------------+
#
# 4. Distance moyenne des vols par continent :
# +----------------+-----------------+
# |origin_continent|avg_distance_km  |
# +----------------+-----------------+
# |africa          |5616.729974472041|
# |asia            |7526.298190276529|
# |europe          |6267.448854789973|
# |maldives        |4292.838158390338|
# |northamerica    |7815.815998435389|
# |oceania         |7615.792109461513|
# |southamerica    |7784.900946980377|
# +----------------+-----------------+
#
# 5. Constructeur avec le plus de vols actifs :
# +------------+-----+
# |constructeur|count|
# +------------+-----+
# |Boeing      |666  |
# +------------+-----+
#
# 6. Top 3 modèles d’avion en usage par pays de compagnie :
# +------------------+-------------+-------+----+
# |origin_country    |aircraft_code|nb_vols|rank|
# +------------------+-------------+-------+----+
# |Angola            |B38M         |1      |1   |
# |Angola            |BCS3         |1      |2   |
# |Argentina         |A332         |2      |1   |
# |Argentina         |B789         |2      |2   |
# |Argentina         |A319         |1      |3   |
# |Australia         |B789         |9      |1   |
# |Australia         |A333         |9      |2   |
# |Australia         |A359         |6      |3   |
# |Austria           |B77W         |1      |1   |
# |Austria           |A321         |1      |2   |
# |Azerbaijan        |B744         |1      |1   |
# |Azerbaijan        |B748         |1      |2   |
# |Bahrain           |A333         |1      |1   |
# |Bangladesh        |B788         |2      |1   |
# |Bangladesh        |B77W         |1      |2   |
# |Belarus           |B738         |2      |1   |
# |Belgium           |B77L         |5      |1   |
# |Belgium           |B744         |2      |2   |
# |Belgium           |B752         |1      |3   |
# |Bolivia           |A332         |1      |1   |
# |Brazil            |B77W         |6      |1   |
# |Brazil            |B789         |5      |2   |
# |Brazil            |B39M         |3      |3   |
# |Canada            |B77W         |7      |1   |
# |Canada            |B789         |5      |2   |
# |Canada            |B77L         |2      |3   |
# |Chile             |B789         |2      |1   |
# |Chile             |B788         |2      |2   |
# |Chile             |B39M         |1      |3   |
# |China             |B77W         |14     |1   |
# |China             |A359         |12     |2   |
# |China             |A332         |12     |3   |
# |Colombia          |B788         |3      |1   |
# |Colombia          |A359         |2      |2   |
# |Colombia          |A320         |1      |3   |
# |Costa Rica        |A359         |1      |1   |
# |Costa Rica        |B738         |1      |2   |
# |Cuba              |B789         |1      |1   |
# |Denmark           |B763         |2      |1   |
# |Denmark           |B788         |1      |2   |
# |Denmark           |B77L         |1      |3   |
# |Dominican Republic|B38M         |1      |1   |
# |Dominican Republic|A320         |1      |2   |
# |Dominican Republic|BCS3         |1      |3   |
# |Ecuador           |A332         |1      |1   |
# |Egypt             |B738         |3      |1   |
# |Egypt             |A20N         |2      |2   |
# |Egypt             |B39M         |1      |3   |
# |El Salvador       |A332         |1      |1   |
# |Ethiopia          |B788         |1      |1   |
# |Ethiopia          |B77L         |1      |2   |
# |Ethiopia          |A359         |1      |3   |
# |Fiji              |B38M         |1      |1   |
# |France            |B77L         |3      |1   |
# |France            |B77W         |3      |2   |
# |France            |A21N         |2      |3   |
# |Georgia           |B738         |2      |1   |
# |Georgia           |B763         |1      |2   |
# |Germany           |B77L         |6      |1   |
# |Germany           |B764         |2      |2   |
# |Germany           |B748         |2      |3   |
# |Ghana             |B38M         |1      |1   |
# |Greece            |B789         |1      |1   |
# |Greece            |A339         |1      |2   |
# |Guam              |B773         |1      |1   |
# |Guyana            |A21N         |1      |1   |
# |Honduras          |A359         |1      |1   |
# |Hong Kong         |B77W         |5      |1   |
# |Hong Kong         |A35K         |4      |2   |
# |Hong Kong         |B744         |4      |3   |
# |India             |B77L         |5      |1   |
# |India             |B763         |3      |2   |
# |India             |B789         |3      |3   |
# |Indonesia         |B77W         |5      |1   |
# |Indonesia         |A333         |3      |2   |
# |Indonesia         |A21N         |2      |3   |
# |Ireland           |C130         |1      |1   |
# |Ireland           |B789         |1      |2   |
# |Israel            |B789         |3      |1   |
# |Israel            |B788         |1      |2   |
# |Israel            |B744         |1      |3   |
# |Italy             |A359         |3      |1   |
# |Italy             |A339         |2      |2   |
# |Italy             |B38M         |2      |3   |
# |Jamaica           |A339         |1      |1   |
# |Jamaica           |B772         |1      |2   |
# |Jamaica           |A333         |1      |3   |
# |Japan             |B789         |10     |1   |
# |Japan             |B77W         |9      |2   |
# |Japan             |B788         |7      |3   |
# |Jordan            |A20N         |2      |1   |
# |Jordan            |A332         |1      |2   |
# |Kazakhstan        |B763         |1      |1   |
# |Kazakhstan        |A21N         |1      |2   |
# |Kazakhstan        |A332         |1      |3   |
# |Kenya             |B788         |3      |1   |
# |Kenya             |B789         |1      |2   |
# |Kuwait            |B77W         |2      |1   |
# |Kuwait            |A20N         |1      |2   |
# |Lithuania         |E3TF         |1      |1   |
# +------------------+-------------+-------+----+
# only showing top 100 rows
#
#  Pipeline terminé avec succès.
#
#
# [🕒] Prochain lancement dans 2 minutes...

# %% [markdown]
# ### Lancement d'un Job chaque 2 heures ( `while True:` pour exécution infinie )

# %%
import time

while True:
    try:
        run_pipeline()
        print(" Pipeline exécutée avec succès.")
    except Exception as e:
        print(f" Erreur : {e}")
    print("\n ")
    print("⏳ En attente de 2h...")
    print("\n ")
    time.sleep(2 * 60 * 60)
